# %% [markdown]
# # EmKa Akademi Bitime Projesi
# ## Ön tanıtım
#
# İnternetten bir film izlemek istediğinizi hayal edin. İnternetteki film puanlamalarına ne kadar güvenebilirsiniz ? *Özellikle* reytingi gösteren aynı şirket sinema bileti satarak da para kazanıyorsa. Sizce de derecelendirme konusunda insanları yanlış yönlendirmesi söz konusu olabilir mi ?
#
# ### Hedef:
#
# **Amacınız aşağıdaki görevleri tamamlayarak *Fandango* websitesinin ratingler konusunda bir yanlış yapıp yapmadığını emin bir şekilde ispatlamak**
#
# ---
# ---
#
# ** Bu da bir sorulu analizdir. Aşağıda sorulan sorulara cevap vermeye ve çıktılara yakın bir çıktı elde etmeye çalışmanız gerekmektedir. **
#
# ---
# ----
#
# ## Part One: Datayı Anlamak

# %% [markdown]
# ### The Data
#
# Elimizde biri şüphelenilen *Fandango* sitsine ait yıldızlar ve film derecelendirmeleri içeriyor. Diğeri ise diğer film sitelerindeki film derecelendirmeleri için veriler içeren toplam 2 csv dosyası vardır.
#
# #### all_sites_scores.csv

# %% [markdown]
# -----
#
# `all_sites_scores.csv` Bütün benzeri sitelerin açıklama kullanıcı puanlamaları bilgilerini ve özellikle 'Rotten Tomatoes(Çürük Elma) adlı bir filme ait başka sitelerdeki puanları içermektedir.'

# %% [markdown]
# Column | Definition
# --- | -----------
# FILM | The film in question
# RottenTomatoes | The Rotten Tomatoes Tomatometer score  for the film
# RottenTomatoes_User | The Rotten Tomatoes user score for the film
# Metacritic | The Metacritic critic score for the film
# Metacritic_User | The Metacritic user score for the film
# IMDB | The IMDb user score for the film
# Metacritic_user_vote_count | The number of user votes the film had on Metacritic
# IMDB_user_vote_count | The number of user votes the film had on IMDb

# %% [markdown]
# ----
# ----
#
# #### fandango_scape.csv

# %% [markdown]
# `fandango_scrape.csv` Fandango sitesine ait 538 film içermektedir
#
# Column | Definiton
# --- | ---------
# FILM | The movie
# STARS | Number of stars presented on Fandango.com
# RATING |  The Fandango ratingValue for the film, as pulled from the HTML of each page. This is the actual average score the movie obtained.
# VOTES | number of people who had reviewed the film at the time we pulled it.

# %% [markdown]
# ----
#
# **TASK: Analizinde işinize yarayacağını düşündüğünüz kütüphanaleri import edin:**

# %%
# Buraya import ediyorsunuz!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Part Two: Fandango sitesini keşfetmeye çalışalım. Gerçek kullanıcı derecelendirmelerini ve site puanlarını yavaştan karşılaştıralım
#
# Fandangonun filmleri puanlama ve derecelendirme konusunda taraflı davranıp davranmadığını analiz etmeye başlayalım !
#
# **TASK: Aşağıdaki fandango_scrape.csv dosyasını çalıştırın**

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %% [markdown]
# **TASK: Fandango verilerini keşfetmeye çalışın. Aşağıdakine benzer çıktılar elde edin.**
#
# # Uyarı ! çıktının tam üstünü kullanmayın. Bir üst hücre satırında çalışmalar yapın.

# %%
# Buraya kodlar yazın
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
# Buraya kod yazmayın !
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.info()
# null değerlerin olup olmadığını öğrendik su anda yok gibi görünüyor.(fandango)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
# Buraya kod yazmayın, üstte yeni bir kod hücresi ekleyip oraya kodlar yazıp aşağıdaki çıktıyı almaya çalışın.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# buradan describe'ına bakıp ortalama bir değerler aldık.
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %%
# Buraya kod yazmayın, üstte yeni bir kod hücresi ekleyip oraya kodlar yazıp aşağıdaki çıktıyı almaya çalışın.
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %% [markdown]
# **TASK: Verimizdeki filmlere ait votes ile rating arasındaki ilişkiyi keşfedelim. Derecelendirme ve oylar arasındaki ilişkiyi gösteren bir scatterplot grafiği oluşturun. Görsel stil eklemeler tamamen size kalmış**

# %%
# Buraya kod yazın
plt.figure(figsize = (11,5))
plt.scatter(fandango["RATING"] ,fandango["VOTES"] , 
            label = ('VOTES','RATING') , alpha = 0.6,
            color= "red"
            
)

plt.xlabel("RATING",size = 20)
plt.ylabel("VOTES" ,size = 20)
plt.legend(loc = "best")

# burdan da "RAING" genelde 3-5 arasında ve "VOTES" 35000 oylama yapan kişi sayısı var

# %% [markdown]
# **TASK: Bütün columnlar arasındaki ilişkiye bakın**

# %%
# Buraya kod yazın.
fandango.corr()
 

# burdan sütunlar arsında bilgler elde ettik. sütunların birbiri ile ilişkilerini öğrendik.
# Out:
# C:\Users\kulme\AppData\Local\Temp\ipykernel_2268\748129145.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fandango.corr()
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %% [markdown]
# **TASK: Bir şekilde 'Yıl' sütunu ekleyin**

# %%
# Buraya kod yazın
def year(x) : 
    return str(x)[-5:-1]


fandango["YEAR"] = fandango["FILM"].apply(year)
fandango

# analizlerimizde yıllara göre kaç film çıkmış gibi yorumları yapabilmek için yıl columunu ekledik.
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %%
# Out:
#                                      FILM  STARS  RATING  VOTES   YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015)
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015)
# 2                  American Sniper (2015)    5.0     4.8  34085  2015)
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015)
# 4                       Inside Out (2015)    4.5     4.5  15749  2015)
# ..                                    ...    ...     ...    ...    ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015)
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015)
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015)
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964)
# 503                         Zarafa (2012)    0.0     0.0      0  2012)
#
# [504 rows x 5 columns]

# %% [markdown]
# **TASK: Elimizdeki Fandango verilerinde yıl başına düşen film sayılarını bulun**

# %%
# Buraya kod yazın
fandango["YEAR"].value_counts()

# mesela en çok film 2015 yılında çıkmış(yayına girmiş) ve 2014 yılından sonra büyük bir atrış yani 1 yılda 455 filmlik
# Out:
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: YEAR, dtype: int64

# %%
# Out:
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: YEAR, dtype: int64

# %% [markdown]
# **TASK: Bir plot ile yıllara düşen film sayılarını görselleştirin:**

# %%
# Buraya kod yazın
sns.countplot(data = fandango , x = "YEAR")
plt.title("Fandango Yıllara Göre Çıkan Film Sayımı" , loc="left")
plt.show()



# burda da yıllara göre filmleri count yani sayım yaptırıp görselleştirdik.Yani 2015 de bu kadar film yayınlandı gibi.
# en düşük film yayınlanan yıllar "2016 , 1964 , 2012"

# %%
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='count'>

# %% [markdown]
# **TASK: En fazla oyu alan 10 film hangileridir?**

# %%
# Buraya kod yazın
fandango["VOTES"].sort_values(ascending=False)
fandango.head(10)

# filmlere oy verenleri fazladan az'a doğru sıraladık ama gariplik yani bir filme 35000 kişi oy vermesi bence çok az
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %% [markdown]
# **TASK: Kaç tane film 0 vote'u aldı ?**

# %%
# Buraya kod yazın
fandango[fandango["VOTES"] == 0]

# null değerlere baktık fakat yoktu gibi gözküyordu ama şimdi baktığımızda ise 0 değerleri gözüküyor yani bir nevi bunlar da null gibi yorumlanabilir
#yani sadece film adı var başka herhangi bir değer yok görünürde.
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 435                        6 Years (2015)    0.0     0.0      0  2015
# 436                      7 Minutes (2015)    0.0     0.0      0  2015
# 437            A Year in Champagne (2015)    0.0     0.0      0  2015
# 438                      Balls Out (2015)    0.0     0.0      0  2015
# 439                  Before I Wake (2015)    0.0     0.0      0  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [69 rows x 5 columns]

# %%
# Out:
# 69

# %% [markdown]
# **TASK: Sıfır oyu olan filmleri kaldırarak yalnızca incelenen filmlerin dataframe'ini oluşturun.**

# %%
# Buraya kod yazın
fandango.tail()
fandango["RATING"] = fandango["RATING"].replace(0,np.nan)
fandango["STARS"] = fandango["STARS"].replace(0,np.nan)
fandango["VOTES"] = fandango["VOTES"].replace(0,np.nan)
fandango[["VOTES","RATING" , "STARS"]]
fandango = fandango.dropna(how="any")
fandango.info()

# 0 olan değerler beni işimi görmez bana "RATING", "VOTES" ve "STARS" da olan değerleri lazım film adını onlar olmadan bir işe yaramaz 
# bu yüzden 0 olan değeri null yapıp drop ettim ki işime yarayanlarla devam edyim
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435 entries, 0 to 434
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    435 non-null    object
#  1   STARS   435 non-null    float64
#  2   RATING  435 non-null    float64
#  3   VOTES   435 non-null    float64
#  4   YEAR    435 non-null    object
# dtypes: float64(3), object(2)
# memory usage: 20.4+ KB

# %% [markdown]
# **TASK: Bazı filmlerde usulsüzlük yapıldığı ve kullanıcılara gösterilen STARS değerlerinin gerçek RATING değerlerinden biraz daha fazla çıktığı düşünüyoruz. 'STARS_DIFF' adında yeni bir column ekleyerek STARS ile RATING arasındaki farkları bu column'da tutun.**

# %%
# Buraya kod yazın
fandango["STARS_DIFF"] = round((fandango["STARS"] - fandango["RATING"]) , 2)
fandango

# "SRTARS" yapanlar ile "RATING" arasında nasıl bir ilişki var, farklarını öğrendik
# Out:
#                                      FILM  STARS  RATING  VOTES  STARS_DIFF
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846         0.1
# 1                   Jurassic World (2015)    4.5     4.5  34390         0.0
# 2                  American Sniper (2015)    5.0     4.8  34085         0.2
# 3                        Furious 7 (2015)    5.0     4.8  33538         0.2
# 4                       Inside Out (2015)    4.5     4.5  15749         0.0
# ..                                    ...    ...     ...    ...         ...
# 499                      Valiyavan (2015)    0.0     0.0      0         0.0
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0         0.0
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0         0.0
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0         0.0
# 503                         Zarafa (2012)    0.0     0.0      0         0.0
#
# [504 rows x 5 columns]

# %%
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [435 rows x 6 columns]

# %% [markdown]
# **TASK: STARS_DIFF sütunundaki verilerin kaçar kez oluştuğunu count edin ve plotlayın**

# %%
# Buraya kod yazın
sns.countplot(data = fandango , x = "STARS_DIFF",)


plt.show()

# "STARS_DIFF" columunu oluşturduktan sonra count yaptırdık fakat her değer neredeye aynı garip şekilde

# %%
# Out:
# <AxesSubplot:xlabel='STARS_DIFF', ylabel='count'>

# %% [markdown]
# **TASK Üstteki plot'dan gördüğümüz üzere STARS_DIFF'i 1 olan film bile var. Bu çok yoğun usulsüzlük yapılan filmi getirin ve inceleyelim.**

# %%
# Buraya kod yazın
fandango.sort_values(["STARS_DIFF"], ascending=False).iloc[0]

# yani değerler birbirne oldukça yakın yani oluslar arası değerle kullanıcı değerleri çok yakın
# Out:
# FILM          Turbo Kid (2015)
# STARS                      5.0
# RATING                     4.0
# VOTES                      2.0
# YEAR                      2015
# STARS_DIFF                 1.0
# Name: 381, dtype: object

# %%
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %% [markdown]
# ## Part Three: Fandango Puanlamalarını Başka Sitelerle Karşılaştıralım
#
# **TASK: "all_sites_scores.csv" dosyasını okuyun**

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %% [markdown]
# **TASK: Bu csv dosyasını da keşfetmek için temel analiz başlangıcı kodlarını yazın.**

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# 4                 19560

# %%
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# 4                 19560

# %%
all_sites.info()

# null değer yok gibi gözüküyor şu anlık
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# min      4.000000                    4.000000            243.000000
# 25%      6.300000                   33.250000           5627.000000
# 50%      6.900000                   72.500000          19103.000000
# 75%      7.400000                  168.500000          45185.750000
# max      8.600000                 2375.000000         334164.000000

# %%
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# min      4.000000                    4.000000            243.000000
# 25%      6.300000                   33.250000           5627.000000
# 50%      6.900000                   72.500000          19103.000000
# 75%      7.400000                  168.500000          45185.750000
# max      8.600000                 2375.000000         334164.000000

# %% [markdown]
# ### Rotten Tomatoes
#
# Önce Rotten Tomatoes'i inceleyelim. RottenTomatoes adında gerçek yorumcuların derecelendirmeleri ve RottenTomatoes_User adında kullanıcıların derecelendirmelerini içeren bir sütun bulunuyor. Bu sütunları plot edelim.
#
# **TASK: Aşağıdaki gibi bir scatterplot oluşturun.**

# %%
# Buraya kod yazın
plt.figure(figsize = (11,6))
sns.scatterplot(data = all_sites , x = "RottenTomatoes" , y= "RottenTomatoes_User")
plt.show()

# %%
# Out:
# (0.0, 100.0)

# %% [markdown]
# **TASK: Rotten DIFF adında bir column oluşturun ve bu column RottenTomatoes-RottenTomatoes_User bilgilerinden oluşsun.**

# %%
# Buraya kod yazın
all_sites["Rotten_dıff"] = all_sites["RottenTomatoes"] - all_sites["RottenTomatoes_User"]
all_sites.head()

# fandango da yaptığımız gibi bir dıff columu oluşturduk
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_dıff
# 0                271107          -12
# 1                 65709            5
# 2                103660          -10
# 3                  3136          -66
# 4                 19560          -14

# %% [markdown]
# **TASK: RT Eleştirmen Puanı ile RT Kullanıcı Puanı arasındaki farkların dağılımını çizin. Bu dağılım grafiğinde negatif değerler olmalıdır. Bu dağıtımı görüntülemek için KDE veya Histogramları kullanabilirsiniz**

# %%
# Buraya kod yazın
plt.figure(figsize=(20,8))
all_sites["Rotten_dıff"].astype(float)
sns.histplot(data = all_sites , x= "Rotten_dıff", binwidth=4 , kde=True)
plt.show()

# %% [markdown]
# **Hadi Kullanıcı ile eleştirmen puanlamaları arasındaki farkın(Rotten_Diff) en yüksek ve en düşük olduğu filmlere bi bakalım.**

# %% [markdown]
# **TASK: Ortalama olarak kullanıcıların, eleştirmenlerden daha fazla sevdiği 5 filmi getirin.**

# %%
# Buraya kod yazın
all_sites.sort_values('Rotten_dıff',ascending=True)[['FILM','Rotten_dıff']].head()
# Out:
#                           FILM  Rotten_dıff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 134    The Longest Ride (2015)          -42
# 105    Hitman: Agent 47 (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %%
# Out:
# Users Love but Critics Hate
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 105    Hitman: Agent 47 (2015)          -42
# 134    The Longest Ride (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %% [markdown]
# **TASK: Şimdi de tam tersi, kullanıcıların eleştirmenlerden bile daha çok sevmediği 5 filmi getirin**

# %%
# Buraya kod yazın
all_sites.sort_values('Rotten_dıff',ascending=False)[['FILM','Rotten_dıff']].head()
# Out:
#                                    FILM  Rotten_dıff
# 69                    Mr. Turner (2014)           42
# 112                   It Follows (2015)           31
# 115            While We're Young (2015)           31
# 145  Kumiko, The Treasure Hunter (2015)           24
# 37                 Welcome to Me (2015)           24

# %%
# Out:
# Critics love, but Users Hate
#                                  FILM  Rotten_Diff
# 69                  Mr. Turner (2014)           42
# 112                 It Follows (2015)           31
# 115          While We're Young (2015)           31
# 37               Welcome to Me (2015)           24
# 40   I'll See You In My Dreams (2015)           24

# %% [markdown]
# ## MetaCritic
#
# Burdan sonraki analizlerde sizi özgür bırakıyoruz. İstediğiniz her şeye bakabilir her türlü incelemeyi ve plot'u çizdirebilirsiniz. Ve en sonunda ulaşmanızı istediğimiz bir sonuç var. *Fandango* sitesi kullanıcıları film puanlamaları konusunda kayda değer ölçüde kandırıyor çünkü .... şeklinde bir karara varmanız ya da *Fandango* sitesi diğer sitelere benzer bir tutum sergiliyor ve herhangi bir yanlış yönlendirme yapmıyor çünkü .... şeklinde bir karara varmanız.
#
# Varacağınız bu kararı maddeler ve kanıtlar halinde notebook'unuzun en altında mantıklı bir şekilde delilleriyle açıklayın. Burada hangi karara varırsanız varın önemli olan ve bizim de EmKa Academy olarak dikkat edeceğimiz şey, ulaştığınız kararı düzgün bir şekilde açıklayabiliyor musunuz ? Asıl odaklandığımız nokta sonuçtan ziyade bu. O yüzden en altta maddeler halinde kararınızı açıklarken dikkatli davranın.

# %%
print(fandango.describe())
print("---" * 10)
print(fandango["YEAR"].value_counts())
print("---" * 10)
print(fandango["VOTES"].value_counts())
print("---" * 10)
sns.countplot(data = fandango , x = "YEAR" )
# Out:
#             STARS      RATING         VOTES  STARS_DIFF
# count  435.000000  435.000000    435.000000  435.000000
# mean     4.122989    3.911264   1329.937931    0.211724
# std      0.706569    0.691447   4094.328212    0.168828
# min      1.000000    1.000000      1.000000    0.000000
# 25%      3.500000    3.500000      6.000000    0.100000
# 50%      4.000000    4.000000     28.000000    0.200000
# 75%      4.500000    4.400000    404.500000    0.300000
# max      5.000000    5.000000  34846.000000    1.000000
# ------------------------------
# 2015    411
# 2014     23
# 2016      1
# Name: YEAR, dtype: int64
# ------------------------------
# 1.0       35
# 4.0       22
# 2.0       19
# 5.0       15
# 8.0       13
#           ..
# 1651.0     1
# 1501.0     1
# 1462.0     1
# 1430.0     1
# 482.0      1
# Name: VOTES, Length: 209, dtype: int64
# ------------------------------
# <Axes: xlabel='YEAR', ylabel='count'>

# %%
 ## Analiz-1: BÜYÜKTEN KÜÇÜĞE DOĞRU SIRALANINCA OLNLAR :
# yani garip şekilde değerler hepi aynı ve nerdeyse farksızlar yani 2015 de ki film 400 küsür tane idi ve "STARS_DIFF" değerleri çok yakın
# 35000 yorum var ve "STARS" ve "RATING" değerleri arasında fark yok nerdeyes yok denecek kadar az 

fandango["RATING"].sort_values(ascending=False)
fandango.sort_values(["VOTES" ,"YEAR"] , ascending=False , inplace=True)
fandango
# Out:
# C:\Users\kulme\AppData\Local\Temp\ipykernel_2268\3545486714.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fandango.sort_values(["VOTES" ,"YEAR"] , ascending=False , inplace=True)
#                             FILM  STARS  RATING    VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846.0  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390.0  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085.0  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538.0  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749.0  2015         0.0
# ..                           ...    ...     ...      ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1.0  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1.0  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1.0  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1.0  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1.0  2015         0.0
#
# [435 rows x 6 columns]

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING    VOTES  YEAR  STARS_DIFF
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846.0  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390.0  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085.0  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538.0  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749.0  2015         0.0

# %%
# analiz -2 

print(all_sites[all_sites["Rotten_dıff"]== 0].value_counts())
print("___" * 60 )

fandango[fandango["STARS_DIFF"] == 0.0].value_counts()
# Out:
# FILM                           RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_dıff
# Escobar: Paradise Lost (2015)  52              52                   56          6.9              6.6   7                           7819                  0              1
# The Last Five Years (2015)     60              60                   60          6.9              6.0   20                          4110                  0              1
# When Marnie Was There (2015)   89              89                   71          6.4              7.8   29                          4160                  0              1
# dtype: int64
# ____________________________________________________________________________________________________________________________________________________________________________________
# FILM                              STARS  RATING  VOTES  STARS_DIFF
# '71 (2015)                        3.5    3.5     192    0.0           1
# 1001 Grams (2015)                 3.0    3.0     2      0.0           1
# Paulo Coelho's Best Story (2015)  0.0    0.0     0      0.0           1
# Queen of Earth  (2015)            0.0    0.0     0      0.0           1
# Reality (2015)                    4.0    4.0     1      0.0           1
#                                                                      ..
# Hungry Hearts (2015)              3.0    3.0     1      0.0           1
# Insanity (2015)                   0.0    0.0     0      0.0           1
# Inside Out (2015)                 4.5    4.5     15749  0.0           1
# Jauja (2015)                      3.0    3.0     2      0.0           1
# Zarafa (2012)                     0.0    0.0     0      0.0           1
# Length: 176, dtype: int64

# %%
fandango["STARS"].value_counts()

# yani çok az sayıda kullanıcı beğenmemiş
# Out:
# 4.0    126
# 4.5    107
# 5.0     92
# 3.5     57
# 3.0     45
# 2.0      4
# 1.0      3
# 2.5      1
# Name: STARS, dtype: int64

# %%
sns.countplot(data = fandango , x = "RATING" )
plt.xticks(rotation = 90)
plt.show()

# yani genel itibari ile "RATING" ' in %85 i 3.0' ın üzerinde demek her film ya çok beğenildi ya da kandırıyor.

# %%
print(all_sites.sort_values(["IMDB_user_vote_count" , "IMDB"]))

print("---" *10)

# all_sites in toplam da en az yorum yapan listede bile sitelerde nerdeyse 7 nin üzernde bir IMDB var
# Out:
#                                                  FILM  RottenTomatoes  \
# 70                    Seymour: An Introduction (2015)             100
# 122                                  Tangerine (2015)              95
# 71                           The Wrecking Crew (2015)              93
# 94                               The Overnight (2015)              82
# 68                              Monkey Kingdom (2015)              94
# ..                                                ...             ...
# 44                Kingsman: The Secret Service (2015)              75
# 74   The Hobbit: The Battle of the Five Armies (2014)              61
# 88                          Mad Max: Fury Road (2015)              97
# 65                                     Birdman (2014)              92
# 14                          The Imitation Game (2014)              90
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 70                    87          83              6.0   7.7
# 122                   86          86              7.3   7.4
# 71                    84          67              7.0   7.8
# 94                    65          65              8.6   6.9
# 68                    77          72              7.5   7.3
# ..                   ...         ...              ...   ...
# 44                    84          58              7.9   7.8
# 74                    75          59              7.0   7.5
# 88                    88          89              8.7   8.3
# 65                    78          88              8.0   7.9
# 14                    92          73              8.2   8.1
#
#      Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_dıff
# 70                            4                   243           13
# 122                          14                   696            9
# 71                            4                   732            9
# 94                           13                   867           17
# 68                           15                   883           17
# ..                          ...                   ...          ...
# 44                         1054                272204           -9
# 74                          903                289464          -14
# 88                         2375                292023            9
# 65                         1171                303505           14
# 14                          566                334164           -2
#
# [146 rows x 9 columns]
# ------------------------------

# %%
all_sites.sort_values(["IMDB"])
# Out:
#                               FILM  RottenTomatoes  RottenTomatoes_User  \
# 48           Fantastic Four (2015)               9                   20
# 97     Fifty Shades of Grey (2015)              25                   42
# 133  Paul Blart: Mall Cop 2 (2015)               5                   36
# 101             The Gallows (2015)              16                   27
# 107       The Vatican Tapes (2015)              13                   21
# ..                             ...             ...                  ...
# 42               About Elly (2015)              97                   86
# 88       Mad Max: Fury Road (2015)              97                   88
# 76   Straight Outta Compton (2015)              90                   94
# 95    The Salt of the Earth (2015)              96                   90
# 140              Inside Out (2015)              98                   90
#
#      Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 48           27              2.5   4.0                         421
# 97           46              3.2   4.2                         778
# 133          13              2.4   4.3                         211
# 101          30              7.0   4.4                          80
# 107          37              5.4   4.6                           5
# ..          ...              ...   ...                         ...
# 42           87              9.6   8.2                          23
# 88           89              8.7   8.3                        2375
# 76           72              7.3   8.4                          90
# 95           83              7.8   8.4                          13
# 140          94              8.9   8.6                         807
#
#      IMDB_user_vote_count  Rotten_dıff
# 48                  39838          -11
# 97                 179506          -17
# 133                 15004          -31
# 101                  5511          -11
# 107                   952           -8
# ..                    ...          ...
# 42                  20659           11
# 88                 292023            9
# 76                  15982           -4
# 95                   6605            6
# 140                 96252            8
#
# [146 rows x 9 columns]

# %%
all_sites["IMDB FARK"] = all_sites["IMDB"] - all_sites["Metacritic_User"]
all_sites.head(10)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
# 5        The Water Diviner (2015)              63                   62
# 6           Irrational Man (2015)              42                   53
# 7                 Top Five (2014)              86                   64
# 8    Shaun the Sheep Movie (2015)              99                   82
# 9             Love & Mercy (2015)              89                   87
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
# 5          50              6.8   7.2                          34
# 6          53              7.6   6.9                          17
# 7          81              6.8   6.5                         124
# 8          81              8.8   7.4                          62
# 9          80              8.5   7.8                          54
#
#    IMDB_user_vote_count  Rotten_dıff  IMDB FARK
# 0                271107          -12        0.7
# 1                 65709            5       -0.4
# 2                103660          -10       -0.3
# 3                  3136          -66        0.7
# 4                 19560          -14        1.7
# 5                 39373            1        0.4
# 6                  2680          -11       -0.7
# 7                 16876           22       -0.3
# 8                 12227           17       -1.4
# 9                  5367            2       -0.7

# %%
sns.countplot(data = all_sites , x= "IMDB")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = all_sites , x= "IMDB" , y = "Metacritic_User")
plt.xticks(rotation = 90)
plt.show()

# burdan da IMDB ile Metacritic_User oranlarını förselleştirdik ve sonucuna baktık.

# %%
sns.countplot(data = fandango , x = "RATING")
plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = fandango , x = "STARS" , y = "RATING")
# Out:
# <Axes: xlabel='STARS', ylabel='RATING'>

# %%
print(fandango.sort_values(["VOTES" , "STARS" , "RATING" ] , ascending=False).head())
print("***" * 30)

print(all_sites.sort_values(["IMDB_user_vote_count" , "IMDB" ] , ascending=False).head())
print("***" * 30)
all_sites["IMDB FARK"].sort_values(ascending=False)

# all_sites de 335000 yorum yapan varken fandango da / 10 şeklinde nerdeyese yani arda bir 10 kat söz konusu
# Out:
#                           FILM  STARS  RATING    VOTES  YEAR  STARS_DIFF
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846.0  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390.0  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085.0  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538.0  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749.0  2015         0.0
# ******************************************************************************************
#                                                 FILM  RottenTomatoes  \
# 14                         The Imitation Game (2014)              90
# 65                                    Birdman (2014)              92
# 88                         Mad Max: Fury Road (2015)              97
# 74  The Hobbit: The Battle of the Five Armies (2014)              61
# 44               Kingsman: The Secret Service (2015)              75
#
#     RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 14                   92          73              8.2   8.1
# 65                   78          88              8.0   7.9
# 88                   88          89              8.7   8.3
# 74                   75          59              7.0   7.5
# 44                   84          58              7.9   7.8
#
#     Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_dıff  IMDB FARK
# 14                         566                334164           -2       -0.1
# 65                        1171                303505           14       -0.1
# 88                        2375                292023            9       -0.4
# 74                         903                289464          -14        0.5
# 44                        1054                272204           -9       -0.1
# ******************************************************************************************
# 35     3.9
# 125    3.4
# 105    2.6
# 109    2.5
# 134    2.4
#       ...
# 121   -1.4
# 64    -1.6
# 94    -1.7
# 83    -1.8
# 101   -2.6
# Name: IMDB FARK, Length: 146, dtype: float64

# %%
all_sites["Rotten_dıff"].sort_values()
# Out:
# 3     -66
# 85    -61
# 134   -42
# 105   -42
# 125   -39
#        ..
# 37     24
# 145    24
# 115    31
# 112    31
# 69     42
# Name: Rotten_dıff, Length: 146, dtype: int64

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_dıff
# 0                271107          -12
# 1                 65709            5
# 2                103660          -10
# 3                  3136          -66
# 4                 19560          -14

# %% [markdown]
# ## Notlarım Kendimce Fikirlerim

# %% [markdown]
# ## FANDANGO YORUMLARI :
#
#
#
# --> null değerlerin olup olmadığını öğrendik yok gibi görünüyor.
#
# -->  "RAItNG" genelde 3-5 arasında ve "VOTES" 35000 oylama yapan kişi sayısı var.
#
# --> mesela en çok film 2015 yılında çıkmış(yayına girmiş) ve 2014 yılından sonra büyük bir atrış yani 1 yılda 455 yayınlanan film sayısı.
#
# --> yıllara göre filmleri count  yaptırıp görselleştirdik.yani 2015 de bu kadar film yayınlandı gibi, yıllara göre en az film yayınlanan "2012, 1946, 2016" yıllarıdır.
#
# --> filmlere oy verenlerin değerlerini büyükten küçüğe doğru sıraladık.
#
# --> null değerlere baktık fakat yoktu gibi gözküyordu ama  0 değerleri gözüküyor yani bir nevi bunlar da null gibi yorumlanabilir, yani sadece film adı var başka herhangi bir değer yok görünürde.
#
# --> null olmayan fakat 0 olan değerleri de null olarak gördüğümüz için onları da null yapıp düşürdük lazım olacağını düşünmüyorum.
#
# --> oy değerleri aynı çıkıyor yani az oy alan da yüksek IMDB(STARS) alıyor fazla olanlar da yüksek değerler alıyor. Yani değerler neredeyse birbirie eşit değerlerde çıkıyor.
#
# --> "Rotten_DIFF" adından yeni bir column açtık ve değerlere baktık birbine çok yakın değerler ve aynı olanalar da mevcut.
#
#
# ## ALL_SİTES YORUMLARI
#
#
# --> null değer gözükmüyor. ve değrleri 0 olan da bir film yok diğer sitelerde neredeyse her sitede değerler var sıfır olan hiçbir film yok.
#
# --> yani yayına girmiş filmler daha fazla oy ve IMDB toplamış
#
# --> null değer yok 0 olan değer yok her filmin her değeri mevcut
#
# --> "IMDB Fark" olarak bi column oluştrduk ve değerlere baktık fandango ile neredeyse aynı değerlerde yani bu değerler de ortalama olarak 1.5 in altında değerer yani kullanıcı IMDB'i ile normal IMDB arasında farkları aynı gözüküyor.

# %% [markdown]
# ## YORUM
# ## *Fandango* sitesi diğer sitelere benzer bir tutum sergiliyor ve herhangi bir yanlış yönlendirme yapmıyor çünkü değerlere baktığımız zaman yani diğer sitelerle neredeyse aynı RATING ve IMDB değerleri almış görünüyüor yani bir anormlallk olsa ("Emincan hocamın bana verdiği yolu izleyerek yorumladım") değerler arası yüksek farklar olurdu yani bence kayda değer bir fazlalık yoktur(IMDB Fark columundan bakabiliriz.). Neticesinde kısaca özetlersek kayda değer bir fazlalık ve farklılık yok gibi gözüküyor diğer sitelerle birlikte baktığımızda değerler aynı anormallik yok gibi.
#
#
# Emincan hocamın da yardı mı ile böyle bir yoruma kanaat getirdim kafam karışıktı iyi mi kötü mü diye taaki emincan hocamın yorumu ile birlikte kendi yorumlarımı ve analizlerimi yaptıkan sonra bu kanıya vardım.
#
#
#
#
#
#  # NOT : Ben bu kadar analiz yapıp bu kadar anlayabildim bu kadar yorum yapabildim hocam ne kadar doğru ne kadar yanlış bilmiyorum "En azından bişeyler öğrenmişim diye düşünüyorum", sayenizde katkılarınızdan dolayı teşekkür ederim Allah razı olsun.

# %% [markdown]
# # BAŞARILAR

# %% [markdown]
# ----
